# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("dataset_Facebook.csv", sep=';')

# %%
d
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
d.head
# Out:
# <bound method NDFrame.head of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
d.describe
# Out:
# <bound method NDFrame.describe of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
d.shape
# Out:
# (500, 19)

# %%
df=d[['Page total likes','Category','Post Month','Post Weekday']].loc[0:15]
df
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 1             139441         2          12             3
# 2             139441         3          12             3
# 3             139441         2          12             2
# 4             139441         2          12             2
# 5             139441         2          12             1
# 6             139441         3          12             1
# 7             139441         3          12             7
# 8             139441         2          12             7
# 9             139441         3          12             6
# 10            139441         2          12             5
# 11            139441         2          12             5
# 12            139441         2          12             5
# 13            139441         2          12             5
# 14            138414         2          12             4
# ...

# %%
a = np.array([1,2,3,4,5,6,7,8])
dd=a.reshape((2,4))
dd
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
df1=d[['Type','Paid','Category']].loc[20:30]
df1
# Out:
#       Type  Paid  Category
# 20   Photo   0.0         2
# 21   Photo   0.0         1
# 22    Link   0.0         1
# 23   Photo   0.0         3
# 24  Status   0.0         2
# 25  Status   0.0         2
# 26  Status   0.0         2
# 27   Photo   0.0         3
# 28   Photo   0.0         2
# 29   Video   1.0         1
# 30   Photo   0.0         2

# %%
df2=d[['Lifetime Post Consumers','Paid','Lifetime Post Total Impressions']].loc[20:30]
df2
# Out:
#     Lifetime Post Consumers  Paid  Lifetime Post Total Impressions
# 20                      142   0.0                             5066
# 21                       15   0.0                             2467
# 22                      104   0.0                             6853
# 23                      118   0.0                             4888
# 24                     1270   0.0                            15294
# 25                     1462   0.0                            15104
# 26                     2531   0.0                            34143
# 27                      124   0.0                             4306
# 28                      559   0.0                            18264
# 29                     1068   1.0                            61262
# 30                      306   0.0                             9390

# %%
merge=pd.concat([df,df1,df2])
merge
# Out:
#     Page total likes  Category  Post Month  Post Weekday    Type  Paid  \
# 0           139441.0       2.0        12.0           4.0     NaN   NaN
# 1           139441.0       2.0        12.0           3.0     NaN   NaN
# 2           139441.0       3.0        12.0           3.0     NaN   NaN
# 3           139441.0       2.0        12.0           2.0     NaN   NaN
# 4           139441.0       2.0        12.0           2.0     NaN   NaN
# 5           139441.0       2.0        12.0           1.0     NaN   NaN
# 6           139441.0       3.0        12.0           1.0     NaN   NaN
# 7           139441.0       3.0        12.0           7.0     NaN   NaN
# 8           139441.0       2.0        12.0           7.0     NaN   NaN
# 9           139441.0       3.0        12.0           6.0     NaN   NaN
# 10          139441.0       2.0        12.0           5.0     NaN   NaN
# 11          139441.0       2.0        12.0           5.0     NaN   NaN
# ...

# %%
sort=d.sort_values('Type',ascending=True)
sort
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 438             98195   Link         2           3             6          6
# 470             91437   Link         1           2             3         13
# 41             138895   Link         1          12             6          3
# 43             138353   Link         1          12             5          3
# 45             138353   Link         1          12             4          3
# ..                ...    ...       ...         ...           ...        ...
# 71             137893  Video         1          11             5          3
# 55             138329  Video         1          11             6          2
# 277            126424  Video         1           6             2         13
# 243            130791  Video         1           7             3         11
# 74             137893  Video         1          11             3         11
#
# ...
